# %% [markdown]
# <h1><u> IDS Final Project: </u> </h1>
# <center><img src="datascience.jpg"></center>
# <ol>
#     <li> <h3>Abhishek Patil</h3> </li>
#     <li> <h3>Manthan B Y</h3> </li>
#     <li> <h3>Monish Prakasan<h3> </li>
# </ol>

# %% [markdown]
# ### Importing the necessary modules

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### Reading the CSV file and storing in a pandas DataFrame

# %%
df = pd.read_csv("AppleStore.csv")

# %%
df.head(5)  #Printing first 5 rows of the dataset
# Out:
#           id                                         track_name  size_bytes  \
# 0  281656475                                    PAC-MAN Premium   100788224
# 1  281796108                          Evernote - stay organized   158578688
# 2  281940292    WeatherBug - Local Weather, Radar, Maps, Alerts   100524032
# 3  282614216  eBay: Best App to Buy, Sell, Save! Online Shop...   128512000
# 4  282935706                                              Bible    92774400
#
#   currency  price  rating_count_tot  rating_count_ver  user_rating  \
# 0      USD   3.99             21292                26          4.0
# 1      USD   0.00            161065                26          4.0
# 2      USD   0.00            188583              2822          3.5
# 3      USD   0.00            262241               649          4.0
# 4      USD   0.00            985920              5320          4.5
#
#    user_rating_ver     ver cont_rating   prime_genre  sup_devices.num  \
# ...

# %% [markdown]
# <h2> Let's See the summary of numerical values in our dataset </h2>

# %%
df.describe() #Getting Summary of the numerical variables
# Out:
#                  id    size_bytes         price  rating_count_tot  \
# count  1.110000e+04  1.110000e+04  11100.000000      1.110000e+04
# mean   9.196595e+08  1.291145e+08      1.119242      8.359482e+03
# std    2.575416e+08  3.044624e+08      4.768515      6.129530e+04
# min    2.816565e+08  0.000000e+00      0.000000      0.000000e+00
# 25%    7.748118e+08  0.000000e+00      0.000000      0.000000e+00
# 50%    1.041344e+09  4.249093e+07      0.000000      2.000000e+01
# 75%    1.106219e+09  1.246930e+08      0.990000      8.192500e+02
# max    1.188524e+09  4.025970e+09    299.990000      2.974676e+06
#
#        rating_count_ver   user_rating  user_rating_ver  sup_devices.num  \
# count      11100.000000  11100.000000     11100.000000     11100.000000
# mean         298.496486      2.286802         2.109550        24.576216
# std         3164.394530      2.080899         2.129825        17.621606
# min            0.000000      0.000000         0.000000         1.000000
# ...

# %% [markdown]
# ## Cleaning the DataSet

# %% [markdown]
# <img src="data-cleaning.png">

# %% [markdown]
# <h4> Converting Size in bytes to MegaBytes </h4>

# %%
for i in range(0,len(df.index)):
    df.at[i, "size_bytes"] = df.at[i, "size_bytes"] / 1048576

# %% [markdown]
# <h4> Renaming the column heading </h4>

# %%
df.rename(columns={'size_bytes': 'size_mb'}, inplace=True)

# %%
ids = df["track_name"]

# %% [markdown]
# <h4> Checking for any duplicate values </h4>

# %%
df[ids.isin(ids[ids.duplicated()])]
# Out:
#                id track_name  size_mb currency  price  rating_count_tot  \
# 18      284971781        NaN        0      NaN    0.0                 0
# 25      286115722        NaN        0      NaN    0.0                 0
# 29      288091002        NaN        0      NaN    0.0                 0
# 37      289567151        NaN        0      NaN    0.0                 0
# 43      291676451        NaN        0      NaN    0.0                 0
# 44      292242503        NaN        0      NaN    0.0                 0
# 45      292411902        NaN        0      NaN    0.0                 0
# 55      294026381        NaN        0      NaN    0.0                 0
# 77      299147843        NaN        0      NaN    0.0                 0
# 87      300915900        NaN        0      NaN    0.0                 0
# 93      302946764        NaN        0      NaN    0.0                 0
# 97      303579255        NaN        0      NaN    0.0                 0
# ...

# %% [markdown]
# <p> We may observe that most of the duplicated values are also null values </p>
# <h4> Removing the duplicated values </h4>

# %%
df.drop_duplicates(subset ="track_name", keep = False, inplace = True)

# %%
df[ids.isin(ids[ids.duplicated()])]
# Out:
# /home/manthangowda/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# Empty DataFrame
# Columns: [id, track_name, size_mb, currency, price, rating_count_tot, rating_count_ver, user_rating, user_rating_ver, ver, cont_rating, prime_genre, sup_devices.num, ipadSc_urls.num, lang.num, vpp_lic, game_enab]
# Index: []

# %%
df
# Out:
#                id                                         track_name  size_mb  \
# 0       281656475                                    PAC-MAN Premium       96
# 1       281796108                          Evernote - stay organized      151
# 2       281940292    WeatherBug - Local Weather, Radar, Maps, Alerts       95
# 3       282614216  eBay: Best App to Buy, Sell, Save! Online Shop...      122
# 4       282935706                                              Bible       88
# 5       283619399                                   Shanghai Mahjong        9
# 6       283646709             PayPal - Send and request money safely      217
# 7       284035177                            Pandora - Music & Radio      124
# 8       284666222                        PCalc - The Best Calculator       46
# 9       284736660                                        Ms. PAC-MAN       66
# 10      284791396                          Solitaire by MobilityWare       47
# ...

# %% [markdown]
# <p>We may observe that all of the dupliacted values are removed.</p>
# <h4> Now let's check for any null values in the dataset</h4>

# %%
df.isnull().any().any()
# Out:
# False

# %% [markdown]
# We may Observe that all the null values are removed in the previous step only and no values are there.

# %%
df.head(5)
# Out:
#           id                                         track_name  size_mb  \
# 0  281656475                                    PAC-MAN Premium       96
# 1  281796108                          Evernote - stay organized      151
# 2  281940292    WeatherBug - Local Weather, Radar, Maps, Alerts       95
# 3  282614216  eBay: Best App to Buy, Sell, Save! Online Shop...      122
# 4  282935706                                              Bible       88
#
#   currency  price  rating_count_tot  rating_count_ver  user_rating  \
# 0      USD   3.99             21292                26          4.0
# 1      USD   0.00            161065                26          4.0
# 2      USD   0.00            188583              2822          3.5
# 3      USD   0.00            262241               649          4.0
# 4      USD   0.00            985920              5320          4.5
#
#    user_rating_ver     ver cont_rating   prime_genre  sup_devices.num  \
# ...

# %%
len(df.index)
# Out:
# 7193

# %%
import plotly.plotly as py
import plotly.graph_objs as go
import plotly.tools as tools
from plotly.tools import FigureFactory as FF
import numpy as np
import pandas as pd
import scipy
import matplotlib.pyplot as plt
import re
import statistics as st
import plotly.offline as offline
import plotly.graph_objs as go
offline.init_notebook_mode()
x1=0
x2=0
x3=0
x4=0
x=0
l=0
clean=[]
for index,rows in df.iterrows():
    l=l+1
    if rows["price"]!="NAN":
        x=x+float(rows['MonthlyCharges'])

me=x/l
for index,rows in df.iterrows():
    if rows["price"]=="NAN":
        rows["price"]=me
    clean.append(float(rows['price'])) 
table = FF.create_table(df)
offline.iplot(table, filename='apple-data-sample')
data = l[0:10]

data_norm_by_std = [number/scipy.std(data) for number in data]

trace1 = go.Histogram(
    x=data,
    opacity=0.75,
    name='data'
)

trace2 = go.Histogram(
    x=data_norm_by_std,
    opacity=0.75,
    name='normalized by std = ' + str(scipy.std(data)),
)

fig = tools.make_subplots(rows=2, cols=1)

fig.append_trace(trace1, 1, 1)
fig.append_trace(trace2, 2, 1)

fig['layout'].update(height=600, width=800, title='Normalize by a Constant')
offline.iplot(fig, filename='apple-data-normalize-constant')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-47-488eeeaba935> in <module>
# ----> 1 import plotly.plotly as py
#       2 import plotly.graph_objs as go
#       3 import plotly.tools as tools
#       4 from plotly.tools import FigureFactory as FF
#       5 import numpy as np
#
# ModuleNotFoundError: No module named 'plotly'

# %% [markdown]
# <h1> Visualizing price distribution of paid apps </h2>

# %%
print ('There are ' + str(sum(df.price == 0)) + ' free apps in the store')
print ('There are ' + str(sum(df.price > 50)) + ' expensive apps in the store')
print ('Apps having price greater than 50$ are considered as expensive apps. They may be considered as outliers for visualization')
print ('Expensive apps constitute ' + str(sum(df.price > 50)/len(df.price)*100) +
       " % of the total Apps")
# Out:
# There are 4052 free apps in the store
# There are 7 expensive apps in the store
# Apps having price greater than 50$ are considered as expensive apps. They may be considered as outliers for visualization
# Expensive apps constitute 0.09731683581259558 % of the total Apps

# %% [markdown]
# <h4>Expensive apps are in less number. Let's print them</h4>

# %%
outlier=df[df.price>50]
outlier
# Out:
#              id                                        track_name  size_mb  \
# 128   308368164                    Proloquo2Go - Symbol-based AAC      690
# 183   320279293                                    NAVIGON Europe      137
# 1323  491998279                          Articulation Station Pro      406
# 1713  551215116                               LAMP Words For Life      556
# 2540  700440156                      Articulation Test Center Pro      166
# 3042  849732663                                       KNFB Reader      101
# 3898  946930094  FineScanner Pro - PDF Document Scanner App + OCR       61
#
#      currency   price  rating_count_tot  rating_count_ver  user_rating  \
# 128       USD  249.99               773                10          4.0
# 183       USD   74.99               927                 3          3.5
# 1323      USD   59.99               294               130          4.5
# 1713      USD  299.99                41                 0          4.0
# ...

# %% [markdown]
# <h4> Now negletting the outliers ( price > 50 )

# %%
paidapps =df[((df.price>0)&(df.price<50))]
paidapps.describe()
# Out:
#                  id      size_mb        price  rating_count_tot  \
# count  3.134000e+03  3134.000000  3134.000000       3134.000000
# mean   8.170940e+08   252.345884     3.675386       4046.844288
# std    2.801736e+08   459.314039     3.791560      25897.579783
# min    2.816565e+08     0.000000     0.990000          0.000000
# 25%    5.459294e+08    35.000000     1.990000         31.000000
# 50%    9.223426e+08    87.000000     2.990000        193.000000
# 75%    1.067207e+09   222.000000     4.990000       1337.500000
# max    1.187780e+09  3839.000000    49.990000     698516.000000
#
#        rating_count_ver  user_rating  user_rating_ver  sup_devices.num  \
# count        3134.00000  3134.000000      3134.000000      3134.000000
# mean          320.25335     3.720006         3.506541        37.284620
# std          3625.51654     1.312679         1.619987         4.545971
# min             0.00000     0.000000         0.000000        11.000000
# ...

# %% [markdown]
# <h3> Maximum and Minimum price </h3>

# %%
print('Max price: ' + str(max(paidapps.price)))
print('Min price: ' + str(min(paidapps.price)))
# Out:
# Max price: 49.99
# Min price: 0.99

# %%
plt.style.use('seaborn-bright')  # To list avaliable styles: print(plt.style.available)
plt.figure(figsize=(15,15))
plt.subplot(2,1,1)

plt.hist(paidapps.price,log=True)  #log scale for better visualization
plt.title('Price distribution of apps (Log scale)',fontsize = 20)
plt.ylabel("Frequency Log scale")
plt.xlabel("Price Distributions in ($) ")

plt.subplot(2,1,2)
plt.title('Visual price distribution',fontsize = 20)
sns.stripplot(data=paidapps,y='price',jitter= True,orient = 'h' ,size=6)
plt.show()

# %% [markdown]
# <h2> Insights </h2>
# <p> 1. Count of paid apps is exponentially decreases as the price increases<br>
# 2. Very few apps have been priced above 30 \$. So if you are building the app better to keep the price below 30\$ </p>

# %% [markdown]
# <h1> Effects of category on price distribution </h1>

# %%
yrange = [0,25]
fsize =15

plt.figure(figsize=(15,10))

plt.subplot(4,1,1)
plt.xlim(yrange)
games = paidapps[paidapps.prime_genre=='Games']
sns.stripplot(data=games,y='price',jitter= True , orient ='h',size=6,color='deeppink')
plt.title('Games',fontsize=fsize)
plt.xlabel('') 

plt.subplot(4,1,2)
plt.xlim(yrange)
ent = paidapps[paidapps.prime_genre=='Entertainment']
sns.stripplot(data=ent,y='price',jitter= True ,orient ='h',size=6,color='darkorange')
plt.title('Entertainment',fontsize=fsize)
plt.xlabel('') 

plt.subplot(4,1,3)
plt.xlim(yrange)
edu = paidapps[paidapps.prime_genre=='Education']
sns.stripplot(data=edu,y='price',jitter= True ,orient ='h' ,size=6,color='deepskyblue')
plt.title('Education',fontsize=fsize)
plt.xlabel('') 

plt.subplot(4,1,4)
plt.xlim(yrange)
pv = paidapps[paidapps.prime_genre=='Photo & Video']
sns.stripplot(data=pv,y='price',jitter= True  ,orient ='h',size=6,color='mediumorchid')
plt.title('Photo & Video',fontsize=fsize)
plt.xlabel('') 

plt.show()

# %% [markdown]
# ### Insights
# - Paid gaming apps are highly priced and distribution extends till 25 $
# - Paid Entertainment apps have a lower price range
# - Highly priced apps are mostly dominated by Games,where as medium pricing range has both games and Educational apps.

# %% [markdown]
# <h1> Free vs Paid Apps </h1>
# <img src="freevspaid.png">

# %%
print("There are total of " + str(len(df.prime_genre.value_counts().index)) + " categories which is little too much")
print ("So we can limit our categories to 5")
# Out:
# There are total of 23 categories which is little too much
# So we can limit our categories to 5

# %%
# reducing the number of categories

s = df.prime_genre.value_counts().index[:4]
def categ(x):
    if x in s:
        return x
    else : 
        return "Others"

df['broad_genre']= df.prime_genre.apply(lambda x : categ(x))

# %%
free = df[df.price==0].broad_genre.value_counts().sort_index().to_frame()
paid = df[df.price>0].broad_genre.value_counts().sort_index().to_frame()
total = df.broad_genre.value_counts().sort_index().to_frame()
free.columns=['free']
paid.columns=['paid']
total.columns=['total']
dist = free.join(paid).join(total) # joining the individual columns
dist ['paid_per'] = dist.paid*100/dist.total
dist ['free_per'] = dist.free*100/dist.total
dist
# Out:
#                free  paid  total   paid_per   free_per
# Education       132   321    453  70.860927  29.139073
# Entertainment   334   201    535  37.570093  62.429907
# Games          2253  1605   3858  41.601866  58.398134
# Others         1166   832   1998  41.641642  58.358358
# Photo & Video   167   182    349  52.148997  47.851003

# %%
list_free= dist.free_per.tolist()
tuple_free = tuple(list_free)
tuple_paidapps = tuple(dist.paid_per.tolist())

# %%
plt.figure(figsize=(15,8))
N=5
ind = np.arange(N)    # the x locations for the groups
width =0.56   # the width of the bars: can also be len(x) sequence

p1 = plt.bar(ind, tuple_free, width, color='#45cea2')
p2 = plt.bar(ind, tuple_paidapps, width,bottom=tuple_free,color='#fdd470')
plt.xticks(ind,tuple(dist.index.tolist() ))
plt.legend((p1[0], p2[0]), ('free', 'paid'))
plt.show()
# for pie chart
pies = dist[['free_per','paid_per']]
pies.columns=['free %','paid %']
plt.show()

# %%
plt.figure(figsize=(15,8))
pies.T.plot.pie(subplots=True,figsize=(20,4),colors=['#45cea2','#fdd470'])
plt.show()

# %% [markdown]
# ### Insights
# - Education has significant % of Paid apps.
# - On the contrary - Entertainment category hosts high % of free apps

# %% [markdown]
# <h1> Are "Paid Apps" worth the money? </h1>

# %%
def paid(x):
    if x>0:
        return 'Paid'
    else :
        return'Free'

df['category']= df.price.apply(lambda x : paid(x))
df.tail()
# Out:
#                id                                 track_name  size_mb  \
# 11080  1187617475                                      Kubik      120
# 11081  1187682390                          VR Roller-Coaster      115
# 11086  1187779532      Bret Michaels Emojis + Lyric Keyboard      106
# 11088  1187838770  VR Roller Coaster World - Virtual Reality       92
# 11096  1188375727               Escape the Sweet Shop Series       86
#
#       currency  price  rating_count_tot  rating_count_ver  user_rating  \
# 11080      USD   0.00               142                75          4.5
# 11081      USD   0.00                30                30          4.5
# 11086      USD   1.99                15                 0          4.5
# 11088      USD   0.00                85                32          4.5
# 11096      USD   0.00                 3                 3          5.0
#
#        user_rating_ver     ver cont_rating prime_genre  sup_devices.num  \
# ...

# %%
plt.figure(figsize=(15,8))
plt.style.use('fast')
plt.ylim([0,5])
plt.title("Distribution of User ratings")
sns.violinplot(data=df, y ='user_rating',x='broad_genre',hue='category',
               vertical=True,kde=False,split=True ,linewidth=2,
               scale ='count', palette=['#fdd470','#45cea2'])
plt.xlabel(" ")
plt.ylabel("Rating (0-5)")

plt.show()
# Out:
# /home/manthangowda/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ## How are the apps distributed category wise ? can we split by paid category ?

# %%
BlueOrangeWapang = ['#fc910d','#fcb13e','#239cd3','#1674b1','#ed6d50']
plt.figure(figsize=(10,10))
label_names=df.broad_genre.value_counts().sort_index().index
size = df.broad_genre.value_counts().sort_index().tolist()
my_circle=plt.Circle( (0,0), 0.5, color='white')
plt.pie(size, labels=label_names, colors=BlueOrangeWapang)
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.show()

# %%
plt.figure(figsize=(10,10))
f=pd.DataFrame(index=np.arange(0,10,2),data=dist.free.values,columns=['num'])
p=pd.DataFrame(index=np.arange(1,11,2),data=dist.paid.values,columns=['num'])
final = pd.concat([f,p],names=['labels']).sort_index()
final.num.tolist()

plt.figure(figsize=(20,20))
group_names=df.broad_genre.value_counts().sort_index().index
group_size=df.broad_genre.value_counts().sort_index().tolist()
h = ['Free', 'Paid']
subgroup_names= 5*h
sub= ['#45cea2','#fdd470']
subcolors= 5*sub
subgroup_size=final.num.tolist()


# First Ring (outside)
fig, ax = plt.subplots()
ax.axis('equal')
mypie, _ = ax.pie(group_size, radius=2.5, labels=group_names, colors=BlueOrangeWapang)
plt.setp( mypie, width=1.2, edgecolor='white')

# Second Ring (Inside)
mypie2, _ = ax.pie(subgroup_size, radius=1.6, labels=subgroup_names, labeldistance=0.7, colors=subcolors)
plt.setp( mypie2, width=0.8, edgecolor='white')
plt.margins(0,0)

# show it
plt.show()

# %% [markdown]
# <h1> Hypotheses Testing </h1>

# %%
import random
from scipy.stats import norm
from math import sqrt
col1=df["user_rating"]
list1=[]
i = 1
while(i<=1000):
    try:
        list1.append(df.at[random.choice(range(0,6000)),"user_rating"])
        i = i + 1
    except:
        continue
def one_sided_hypo(sample_mean, pop_mean, std_dev, sample_size, alpha):
    actual_z = abs(norm.ppf(alpha))
    hypo_z = (sample_mean - pop_mean) / (std_dev/sqrt(sample_size))
    print('actual z value :', actual_z)
    print('hypothesis z value :', hypo_z, '\n')
    if hypo_z >= actual_z:
        return True
    else:
        return False
    
alpha = 0.05
sample_mean = np.mean(list1)
pop_mean = np.mean(col1)
sample_size =  1000
std_dev = np.std(list1)

print("Sample mean=",sample_mean)
print("Standard Deviation=",std_dev)
print("Population mean=",pop_mean)
print("Sample Size=",sample_size)
print('H0 : μ <=', pop_mean)
print('H1 : μ >', pop_mean)
print('alpha value is :', alpha, '\n')

r = one_sided_hypo(sample_mean, pop_mean, std_dev, sample_size, alpha)
if r:
    print('Reject NULL hypothesis')
else:
    print('Failed to reject NULL hypothesis')
    
    
print("\nTwo sided hypothesis testing")

def two_sided_hypo(sample_mean, pop_mean, std_dev, sample_size, alpha):
    actual_z = abs(norm.ppf(alpha/2))
    hypo_z = (sample_mean - pop_mean) / (std_dev/sqrt(sample_size))
    print('actual z value :', actual_z)
    print('hypothesis z value :', hypo_z, '\n')
    if hypo_z >= actual_z or hypo_z <= -(actual_z):
        return True
    else:
        return False
    

    
col1=df["size_mb"]
list1=[]
i = 1
while(i<=1000):
    try:
        list1.append(df.at[random.choice(range(0,6000)),"size_mb"])
        i = i + 1
    except:
        continue
        
alpha = 0.05
sample_mean = np.mean(list1)
pop_mean = np.mean(col1)
sample_size =  1000
std_dev = np.std(col1)

print('H0 : μ =', pop_mean)
print('H1 : μ !=', pop_mean)
print('alpha value is :', alpha, '\n')

r = two_sided_hypo(sample_mean, pop_mean, std_dev, sample_size, alpha)
if r:
    print('Reject NULL hypothesis')
else:
    print('Failed to reject NULL hypothesis')
# Out:
# Sample mean= 3.748
# Standard Deviation= 1.2505982568355036
# Population mean= 3.526970665925205
# Sample Size= 1000
# H0 : μ <= 3.526970665925205
# H1 : μ > 3.526970665925205
# alpha value is : 0.05
#
# actual z value : 1.6448536269514729
# hypothesis z value : 5.588974089530932
#
# Reject NULL hypothesis
#
# Two sided hypothesis testing
# H0 : μ = 189.43639649659391
# H1 : μ != 189.43639649659391
# alpha value is : 0.05
#
# actual z value : 1.9599639845400545
# hypothesis z value : 0.7621334178126115
#
# Failed to reject NULL hypothesis

# %%
df.head(50)
# Out:
#            id                                         track_name  size_mb  \
# 0   281656475                                    PAC-MAN Premium       96
# 1   281796108                          Evernote - stay organized      151
# 2   281940292    WeatherBug - Local Weather, Radar, Maps, Alerts       95
# 3   282614216  eBay: Best App to Buy, Sell, Save! Online Shop...      122
# 4   282935706                                              Bible       88
# 5   283619399                                   Shanghai Mahjong        9
# 6   283646709             PayPal - Send and request money safely      217
# 7   284035177                            Pandora - Music & Radio      124
# 8   284666222                        PCalc - The Best Calculator       46
# 9   284736660                                        Ms. PAC-MAN       66
# 10  284791396                          Solitaire by MobilityWare       47
# 11  284815117                                   SCRABBLE Premium      217
# ...

# %%
from sklearn import preprocessing

x = df.values #returns a numpy array
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
df = pandas.DataFrame(x_scaled)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-57-05e4ff1e3e98> in <module>
#       3 x = df.values #returns a numpy array
#       4 min_max_scaler = preprocessing.MinMaxScaler()
# ----> 5 x_scaled = min_max_scaler.fit_transform(x)
#       6 df = pandas.DataFrame(x_scaled)
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     460         if y is None:
#     461             # fit method of arity 1 (unsupervised transformation)
# --> 462             return self.fit(X, **fit_params).transform(X)
#     463         else:
#     464             # fit method of arity 2 (supervised transformation)
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/data.py in fit(self, X, y)
#     321         # Reset internal state before fitting
#     322         self._reset()
# ...

# %%
top_trending_paid_apps = trend_ratings[(trend_ratings["prime_genre"]!="Games") & (trend_ratings["price"]!=0)]
top_trending_paid_apps.head(10)
